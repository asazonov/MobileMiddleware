# %%
import pandas as pd
import matplotlib as mpl
import glob
import numpy
import random
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/pytz/__init__.py:35: UserWarning: Module logging was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/logging/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
data_list2 = []
file_list2 = []
file_list2 = glob.glob("./output/100-*.csv")
for file in file_list2:
    tmp_data2 = pd.read_csv(file)
    data_list2.append(tmp_data2)
    
data_list3 = []
file_list3 = []
file_list3 = glob.glob("./output/150-*.csv")
for file in file_list3:
    tmp_data3 = pd.read_csv(file)
    data_list3.append(tmp_data3)
    
data_list4 = []
file_list4 = []
file_list4 = glob.glob("./output/300-*.csv")
for file in file_list4:
    tmp_data4 = pd.read_csv(file)
    data_list4.append(tmp_data4)

# %%
data_list4
# Out:
# [<class 'pandas.core.frame.DataFrame'>
# Int64Index: 657 entries, 0 to 656
# Data columns (total 6 columns):
# sensor       657  non-null values
# lat          657  non-null values
# lng          657  non-null values
# data         657  non-null values
# timestamp    657  non-null values
# time         657  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 657 entries, 0 to 656
# Data columns (total 6 columns):
# sensor       657  non-null values
# lat          657  non-null values
# lng          657  non-null values
# data         657  non-null values
# timestamp    657  non-null values
# time         657  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 639 entries, 0 to 638
# Data columns (total 6 columns):
# sensor       639  non-null values
# lat          639  non-null values
# lng          639  non-null values
# data         639  non-null values
# ...

# %%
plt.figure(figsize=(30,10))
for data in data_list4:
    #print data
    if data.empty:
        print "hi"
        continue
    data.plot(y="time", style = "x", c='pink')#numpy.random.rand(3,))
for data in data_list3:
    data.plot(y="time", style = "x", c='green')#numpy.random.rand(3,))
for data in data_list2:
    data.plot(y="time", style = "x", c='red')#numpy.random.rand(3,))
for data in data_list:
    data.plot(y="time", style = "x", c='blue')#numpy.random.rand(3,))

#plt.savefig("broker-test.png", format='png')

# %%
from collections import OrderedDict

plt.figure(figsize=(15,10))

prefixes = {10 : "red", 20 : "orange", 40 : "yellow", 80 : "green", 160 : "blue", 320 : "violet" }
prefix_list = [10, 20, 40, 80, 160, 320]

for prefix in reversed(prefix_list):
    data_list = []
    file_list = []
    file_list = glob.glob("./output-0.001/" + str(prefix) + "-*.csv")
    for file in file_list:
        tmp_data = pd.read_csv(file)
        data_list.append(tmp_data)
    col = numpy.random.rand(3,)
    for data in data_list: 
        data = data[(data.time < 10000)]
        if data.empty:
            print "hi"
            continue
        data.plot(y="time", style = "x", c=prefixes[prefix])  #c='pink')
    #plt.axis([0, 10, 0, 10])
    xlabel("Messages recieved")
    ylabel("Turnaround time (s)")
#legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
"
# Out:
#   File "<ipython-input-14-3af0bf9dc137>", line 1
#     "
#     ^
# SyntaxError: EOL while scanning string literal
