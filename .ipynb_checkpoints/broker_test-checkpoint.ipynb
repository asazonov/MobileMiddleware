# %%
import pandas as pd
import matplotlib as mpl
import glob
import numpy
import random

# %%
data_list = []
file_list = []
file_list = glob.glob("./output/10-*.csv")
for file in file_list:
    tmp_data = pd.read_csv(file)
    data_list.append(tmp_data)
data_list2 = []
file_list2 = []
file_list2 = glob.glob("./output/100-*.csv")
for file in file_list2:
    tmp_data2 = pd.read_csv(file)
    data_list2.append(tmp_data2)
    
data_list3 = []
file_list3 = []
file_list3 = glob.glob("./output/150-*.csv")
for file in file_list3:
    tmp_data3 = pd.read_csv(file)
    data_list3.append(tmp_data3)
    
data_list4 = []
file_list4 = []
file_list4 = glob.glob("./output/300-*.csv")
for file in file_list4:
    tmp_data4 = pd.read_csv(file)
    data_list4.append(tmp_data4)

# %%
data_list4
# Out:
# [<class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 0 to 485
# Data columns (total 6 columns):
# sensor       486  non-null values
# lat          486  non-null values
# lng          486  non-null values
# data         486  non-null values
# timestamp    486  non-null values
# time         486  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns (total 6 columns):
# sensor       480  non-null values
# lat          480  non-null values
# lng          480  non-null values
# data         480  non-null values
# timestamp    480  non-null values
# time         480  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 0 to 482
# Data columns (total 6 columns):
# sensor       483  non-null values
# lat          483  non-null values
# lng          483  non-null values
# data         483  non-null values
# timestamp    483  non-null values
# time         483  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns (total 6 columns):
# sensor       480  non-null values
# lat          480  non-null values
# lng          480  non-null values
# data         480  non-null values
# timestamp    480  non-null values
# time         480  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 471 entries, 0 to 470
# Data columns (total 6 columns):
# sensor       471  non-null values
# lat          471  non-null values
# lng          471  non-null values
# data         471  non-null values
# timestamp    471  non-null values
# time         471  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 0 to 485
# Data columns (total 6 columns):
# sensor       486  non-null values
# lat          486  non-null values
# lng          486  non-null values
# data         486  non-null values
# timestamp    486  non-null values
# time         486  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 501 entries, 0 to 500
# Data columns (total 6 columns):
# sensor       501  non-null values
# lat          501  non-null values
# lng          501  non-null values
# data         501  non-null values
# timestamp    501  non-null values
# time         501  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 0 to 482
# Data columns (total 6 columns):
# sensor       483  non-null values
# lat          483  non-null values
# lng          483  non-null values
# data         483  non-null values
# timestamp    483  non-null values
# time         483  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 6 columns):
# sensor       441  non-null values
# lat          441  non-null values
# lng          441  non-null values
# data         441  non-null values
# timestamp    441  non-null values
# time         441  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489 entries, 0 to 488
# Data columns (total 6 columns):
# sensor       489  non-null values
# lat          489  non-null values
# lng          489  non-null values
# data         489  non-null values
# timestamp    489  non-null values
# time         489  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 491
# Data columns (total 6 columns):
# sensor       492  non-null values
# lat          492  non-null values
# lng          492  non-null values
# data         492  non-null values
# timestamp    492  non-null values
# time         492  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465 entries, 0 to 464
# Data columns (total 6 columns):
# sensor       465  non-null values
# lat          465  non-null values
# lng          465  non-null values
# data         465  non-null values
# timestamp    465  non-null values
# time         465  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 507 entries, 0 to 506
# Data columns (total 6 columns):
# sensor       507  non-null values
# lat          507  non-null values
# lng          507  non-null values
# data         507  non-null values
# timestamp    507  non-null values
# time         507  non-null values
# dtypes: float64(3), object(3),
#  Empty DataFrame
# Columns: [sensor, lat, lng, data, timestamp, time]
# Index: [],
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  Empty DataFrame
# Columns: [sensor, lat, lng, data, timestamp, time]
# Index: [],
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 491
# Data columns (total 6 columns):
# sensor       492  non-null values
# lat          492  non-null values
# lng          492  non-null values
# data         492  non-null values
# timestamp    492  non-null values
# time         492  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498 entries, 0 to 497
# Data columns (total 6 columns):
# sensor       498  non-null values
# lat          498  non-null values
# lng          498  non-null values
# data         498  non-null values
# timestamp    498  non-null values
# time         498  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns (total 6 columns):
# sensor       480  non-null values
# lat          480  non-null values
# lng          480  non-null values
# data         480  non-null values
# timestamp    480  non-null values
# time         480  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 491
# Data columns (total 6 columns):
# sensor       492  non-null values
# lat          492  non-null values
# lng          492  non-null values
# data         492  non-null values
# timestamp    492  non-null values
# time         492  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 0 to 437
# Data columns (total 6 columns):
# sensor       438  non-null values
# lat          438  non-null values
# lng          438  non-null values
# data         438  non-null values
# timestamp    438  non-null values
# time         438  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 504 entries, 0 to 503
# Data columns (total 6 columns):
# sensor       504  non-null values
# lat          504  non-null values
# lng          504  non-null values
# data         504  non-null values
# timestamp    504  non-null values
# time         504  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 0 to 509
# Data columns (total 6 columns):
# sensor       510  non-null values
# lat          510  non-null values
# lng          510  non-null values
# data         510  non-null values
# timestamp    510  non-null values
# time         510  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# timestamp    435  non-null values
# time         435  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 6 columns):
# sensor       435  non-null values
# lat          435  non-null values
# lng          435  non-null values
# data         435  non-null values
# ...
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465 entries, 0 to 464
# Data columns (total 6 columns):
# sensor       465  non-null values
# lat          465  non-null values
# lng          465  non-null values
# data         465  non-null values
# timestamp    465  non-null values
# time         465  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 471 entries, 0 to 470
# Data columns (total 6 columns):
# sensor       471  non-null values
# lat          471  non-null values
# lng          471  non-null values
# data         471  non-null values
# timestamp    471  non-null values
# time         471  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 477 entries, 0 to 476
# Data columns (total 6 columns):
# sensor       477  non-null values
# lat          477  non-null values
# lng          477  non-null values
# data         477  non-null values
# timestamp    477  non-null values
# time         477  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 0 to 485
# Data columns (total 6 columns):
# sensor       486  non-null values
# lat          486  non-null values
# lng          486  non-null values
# data         486  non-null values
# timestamp    486  non-null values
# time         486  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 459 entries, 0 to 458
# Data columns (total 6 columns):
# sensor       459  non-null values
# lat          459  non-null values
# lng          459  non-null values
# data         459  non-null values
# timestamp    459  non-null values
# time         459  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456 entries, 0 to 455
# Data columns (total 6 columns):
# sensor       456  non-null values
# lat          456  non-null values
# lng          456  non-null values
# data         456  non-null values
# timestamp    456  non-null values
# time         456  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462 entries, 0 to 461
# Data columns (total 6 columns):
# sensor       462  non-null values
# lat          462  non-null values
# lng          462  non-null values
# data         462  non-null values
# timestamp    462  non-null values
# time         462  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456 entries, 0 to 455
# Data columns (total 6 columns):
# sensor       456  non-null values
# lat          456  non-null values
# lng          456  non-null values
# data         456  non-null values
# timestamp    456  non-null values
# time         456  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 453 entries, 0 to 452
# Data columns (total 6 columns):
# sensor       453  non-null values
# lat          453  non-null values
# lng          453  non-null values
# data         453  non-null values
# timestamp    453  non-null values
# time         453  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465 entries, 0 to 464
# Data columns (total 6 columns):
# sensor       465  non-null values
# lat          465  non-null values
# lng          465  non-null values
# data         465  non-null values
# timestamp    465  non-null values
# time         465  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 501 entries, 0 to 500
# Data columns (total 6 columns):
# sensor       501  non-null values
# lat          501  non-null values
# lng          501  non-null values
# data         501  non-null values
# timestamp    501  non-null values
# time         501  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465 entries, 0 to 464
# Data columns (total 6 columns):
# sensor       465  non-null values
# lat          465  non-null values
# lng          465  non-null values
# data         465  non-null values
# timestamp    465  non-null values
# time         465  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456 entries, 0 to 455
# Data columns (total 6 columns):
# sensor       456  non-null values
# lat          456  non-null values
# lng          456  non-null values
# data         456  non-null values
# timestamp    456  non-null values
# time         456  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456 entries, 0 to 455
# Data columns (total 6 columns):
# sensor       456  non-null values
# lat          456  non-null values
# lng          456  non-null values
# data         456  non-null values
# timestamp    456  non-null values
# time         456  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 453 entries, 0 to 452
# Data columns (total 6 columns):
# sensor       453  non-null values
# lat          453  non-null values
# lng          453  non-null values
# data         453  non-null values
# timestamp    453  non-null values
# time         453  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465 entries, 0 to 464
# Data columns (total 6 columns):
# sensor       465  non-null values
# lat          465  non-null values
# lng          465  non-null values
# data         465  non-null values
# timestamp    465  non-null values
# time         465  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns (total 6 columns):
# sensor       480  non-null values
# lat          480  non-null values
# lng          480  non-null values
# data         480  non-null values
# timestamp    480  non-null values
# time         480  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489 entries, 0 to 488
# Data columns (total 6 columns):
# sensor       489  non-null values
# lat          489  non-null values
# lng          489  non-null values
# data         489  non-null values
# timestamp    489  non-null values
# time         489  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456 entries, 0 to 455
# Data columns (total 6 columns):
# sensor       456  non-null values
# lat          456  non-null values
# lng          456  non-null values
# data         456  non-null values
# timestamp    456  non-null values
# time         456  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 449
# Data columns (total 6 columns):
# sensor       450  non-null values
# lat          450  non-null values
# lng          450  non-null values
# data         450  non-null values
# timestamp    450  non-null values
# time         450  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 504 entries, 0 to 503
# Data columns (total 6 columns):
# sensor       504  non-null values
# lat          504  non-null values
# lng          504  non-null values
# data         504  non-null values
# timestamp    504  non-null values
# time         504  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 453 entries, 0 to 452
# Data columns (total 6 columns):
# sensor       453  non-null values
# lat          453  non-null values
# lng          453  non-null values
# data         453  non-null values
# timestamp    453  non-null values
# time         453  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 443
# Data columns (total 6 columns):
# sensor       444  non-null values
# lat          444  non-null values
# lng          444  non-null values
# data         444  non-null values
# timestamp    444  non-null values
# time         444  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3),
#  <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 446
# Data columns (total 6 columns):
# sensor       447  non-null values
# lat          447  non-null values
# lng          447  non-null values
# data         447  non-null values
# timestamp    447  non-null values
# time         447  non-null values
# dtypes: float64(3), object(3)]

# %%
plt.figure(figsize=(30,30))
for data in data_list3:
    data.plot(y="time", style = "x", c='green')#numpy.random.rand(3,))
for data in data_list2:
    data.plot(y="time", style = "x", c='red')#numpy.random.rand(3,))
for data in data_list:
    data.plot(y="time", style = "x", c='blue')#numpy.random.rand(3,))
for data in data_list4:
    data.plot(y="time", style = "x", c='pink')#numpy.random.rand(3,))

#plt.savefig("broker-test.png", format='png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-cd8f325373d1> in <module>()
#       1 plt.figure(figsize=(30,30))
#       2 for data in data_list4:
# ----> 3     data.plot(y="time", style = "x", c='pink')#numpy.random.rand(3,))
#       4 for data in data_list3:
#       5     data.plot(y="time", style = "x", c='green')#numpy.random.rand(3,))
#
# /Library/Python/2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(frame, x, y, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, style, title, xlim, ylim, logx, logy, xticks, yticks, kind, sort_columns, fontsize, secondary_y, **kwds)
#    1625                            grid=grid, logx=logx, logy=logy,
#    1626                            secondary_y=secondary_y, title=title,
# -> 1627                            figsize=figsize, fontsize=fontsize, **kwds)
#    1628
#    1629     plot_obj = klass(frame, kind=kind, subplots=subplots, rot=rot,
#
# /Library/Python/2.7/site-packages/pandas/tools/plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    1728                      secondary_y=secondary_y, **kwds)
#    1729
# -> 1730     plot_obj.generate()
#    1731     plot_obj.draw()
#    1732
#
# /Library/Python/2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     852     def generate(self):
#     853         self._args_adjust()
# --> 854         self._compute_plot_data()
#     855         self._setup_subplots()
#     856         self._make_plot()
#
# /Library/Python/2.7/site-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#     936                 # still an object dtype so we can't plot it
#     937                 if numeric_data.dtype == np.object_:
# --> 938                     raise TypeError('Series has object dtype and cannot be'
#     939                                     ' converted: no numeric data to plot')
#     940
#
# TypeError: Series has object dtype and cannot be converted: no numeric data to plot
